# %% [markdown]
# # GroupBy
#
# Single Key, Multiple Keys

# %% [markdown]
# #### Create a subset and group by, aggregating the row indexes
# We want to maintain the original indices of the data coming in if we can.

# %%
import apache_beam as beam
from apache_beam.dataframe.io import read_csv
from apache_beam.dataframe.convert import to_dataframe
from apache_beam.dataframe.convert import to_pcollection

import os

# Configure some test data
test_file_path = os.path.join(os.getcwd(), 'assets', 'data', 'usbe_students.csv')
output_file_path = os.path.join(os.getcwd(), 'output_test_file.csv')


# Define a subset to work with
agg_set = ['FIRST_NAME', 'LAST_NAME']  # Can be any number of valid columns in dataset

# %% [markdown]
# ## Via Pure CombineFn, Pipeline Operations

# %%
from utils.load import (
    make_schema_from_csv,
    make_csv_coder,
)
from assets.mapping import is_mapped

class CompositeKey(beam.DoFn):
    def __init__(self, agg_keys: list = []):
        self.agg_keys = agg_keys
        
    def process(self, row: dict):
        row['agg_key'] = {'-'.join([row[k] for k in self.agg_keys])}
        yield row
    

# Convert over to mapped column names
mapped_set = [is_mapped(col)[0] for col in agg_set]
    

with beam.Pipeline() as p:
    schema = make_schema_from_csv(test_file_path)
    csv_coder = make_csv_coder(schema)
    
    grouped = (
        p
        | 'ReadFromText' >> beam.io.ReadFromText(
            test_file_path,
            skip_header_lines=1
            )
        | 'ParseCSV' >> beam.Map(csv_coder)
        | 'Create Composite Key' >> beam.ParDo(CompositeKey(agg_keys=mapped_set))
        | 'GroupBy Keys' >> beam.GroupBy(lambda r: r['agg_key'])  # Now grouped by composite key
            # If there was a row-index column, then you can aggregate the columns via CombinePerKey
        | 'Print' >> beam.Map(print)
    )
# Out:
# ({'Genora-Zegarra'}, [{'birth_date_pool': '6/9/1256', 'FIRST_ENTERED_US': '07-MAR-16 12.00.00.000000000 AM', 'first_name_pool': 'Genora', 'gender_pool': 'f', 'last_name_pool': 'Zegarra', 'middle_name_pool': 'Rhino', 'ssid_pool': '0x218b2ea30x43165d46', 'student_id_pool': '666165', 'id': '46394', 'agg_key': {'Genora-Zegarra'}}])
# ({'Laramee-Vela Garcia'}, [{'birth_date_pool': '9/5/1287', 'FIRST_ENTERED_US': '13-AUG-12 12.00.00.000000000 AM', 'first_name_pool': 'Laramee', 'gender_pool': 'm', 'last_name_pool': 'Vela Garcia', 'middle_name_pool': 'Legacy-Martin', 'ssid_pool': '0x2156f0e80x42ade1d0', 'student_id_pool': '976990', 'id': '35263', 'agg_key': {'Laramee-Vela Garcia'}}])
# ({'Zelma-Garlitz'}, [{'birth_date_pool': '3/11/1507', 'FIRST_ENTERED_US': '06-OCT-16 12.00.00.000000000 AM', 'first_name_pool': 'Zelma', 'gender_pool': 'n', 'last_name_pool': 'Garlitz', 'middle_name_pool': 'Katempa', 'ssid_pool': '0x2981558d0x5302ab1a', 'student_id_pool': '225275', 'id': '148149', 'agg_key': {'Zelma-Garlitz'}}])
# ({'Rynale-Reuter'}, [{'birth_date_pool': '3/11/1898', 'FIRST_ENTERED_US': '24-FEB-97 12.00.00.000000000 AM', 'first_name_pool': 'Rynale', 'gender_pool': 'n', 'last_name_pool': 'Reuter', 'middle_name_pool': 'Javien', 'ssid_pool': '0x175401eb0x2ea803d6', 'student_id_pool': '445502272', 'id': '126536', 'agg_key': {'Rynale-Reuter'}}])
# ({'Weslee-Cavalcante'}, [{'birth_date_pool': '1/5/2380', 'FIRST_ENTERED_US': '05-SEP-05 12.00.00.000000000 AM', 'first_name_pool': 'Weslee', 'gender_pool': 'n', 'last_name_pool': 'Cavalcante', 'middle_name_pool': 'Milam', 'ssid_pool': '0x286b652b0x50d6ca56', 'student_id_pool': '437170', 'id': '105139', 'agg_key': {'Weslee-Cavalcante'}}])
# ({'Paisa-Oguey'}, [{'birth_date_pool': '2/13/2455', 'FIRST_ENTERED_US': '10-AUG-08 12.00.00.000000000 AM', 'first_name_pool': 'Paisa', 'gender_pool': 'f', 'last_name_pool': 'Oguey', 'middle_name_pool': 'Neville', 'ssid_pool': '0x34f34a190x69e69432', 'student_id_pool': '643753', 'id': '88797', 'agg_key': {'Paisa-Oguey'}}])
# ({'Hopelynn-Motter'}, [{'birth_date_pool': '1/21/1470', 'FIRST_ENTERED_US': '27-FEB-94 12.00.00.000000000 AM', 'first_name_pool': 'Hopelynn', 'gender_pool': 'f', 'last_name_pool': 'Motter', 'middle_name_pool': 'Jemelle', 'ssid_pool': '0x18d72c3a0x31ae5874', 'student_id_pool': '945046', 'id': '77368', 'agg_key': {'Hopelynn-Motter'}}])
# ({'Shevelle-Curtin'}, [{'birth_date_pool': '11/4/2967', 'FIRST_ENTERED_US': '07-JAN-09 12.00.00.000000000 AM', 'first_name_pool': 'Shevelle', 'gender_pool': 'm', 'last_name_pool': 'Curtin', 'middle_name_pool': 'Iker', 'ssid_pool': '0xd8d7b640x1b1af6c8', 'student_id_pool': '360659', 'id': '88759', 'agg_key': {'Shevelle-Curtin'}}])
# ({'Maoai-Reyes Dominguez'}, [{'birth_date_pool': '2/21/2025', 'FIRST_ENTERED_US': '05-MAY-95 12.00.00.000000000 AM', 'first_name_pool': 'Maoai', 'gender_pool': 'n', 'last_name_pool': 'Reyes Dominguez', 'middle_name_pool': 'Briana', 'ssid_pool': '0x1ab388030x35671006', 'student_id_pool': '249729', 'id': '70221', 'agg_key': {'Maoai-Reyes Dominguez'}}])
# ({'Carsen-VanDenover'}, [{'birth_date_pool': '2/25/2215', 'FIRST_ENTERED_US': '04-JAN-12 12.00.00.000000000 AM', 'first_name_pool': 'Carsen', 'gender_pool': 'm', 'last_name_pool': 'VanDenover', 'middle_name_pool': 'Susan Jeanne', 'ssid_pool': '0x2320d97c0x4641b2f8', 'student_id_pool': '671835959', 'id': '113413', 'agg_key': {'Carsen-VanDenover'}}])
# ({'Taela-Zilotin'}, [{'birth_date_pool': '11/22/2851', 'FIRST_ENTERED_US': '26-JUL-08 12.00.00.000000000 AM', 'first_name_pool': 'Taela', 'gender_pool': 'm', 'last_name_pool': 'Zilotin', 'middle_name_pool': 'McKrae', 'ssid_pool': '0x398a19b20x73143364', 'student_id_pool': '376727', 'id': '142986', 'agg_key': {'Taela-Zilotin'}}])
# ({'Emeline-Orozco Alvarado'}, [{'birth_date_pool': '10/27/2112', 'FIRST_ENTERED_US': '05-FEB-01 12.00.00.000000000 AM', 'first_name_pool': 'Emeline', 'gender_pool': 'm', 'last_name_pool': 'Orozco Alvarado', 'middle_name_pool': 'Wyatt William', 'ssid_pool': '0x191bcd320x32379a64', 'student_id_pool': '581373', 'id': '7456', 'agg_key': {'Emeline-Orozco Alvarado'}}])
# ({'Lorriel-Garcia Alejandre'}, [{'birth_date_pool': '1/5/1635', 'FIRST_ENTERED_US': '10-MAR-09 12.00.00.000000000 AM', 'first_name_pool': 'Lorriel', 'gender_pool': 'n', 'last_name_pool': 'Garcia Alejandre', 'middle_name_pool': 'Kahawai Pahiwa', 'ssid_pool': '0x1da5a2c00x3b4b4580', 'student_id_pool': '610233', 'id': '85662', 'agg_key': {'Lorriel-Garcia Alejandre'}}])
# ({'Franchesca Belle-McDonald'}, [{'birth_date_pool': '9/26/1682', 'FIRST_ENTERED_US': '16-MAR-99 12.00.00.000000000 AM', 'first_name_pool': 'Franchesca Belle', 'gender_pool': 'n', 'last_name_pool': 'McDonald', 'middle_name_pool': 'Haas', 'ssid_pool': '0x3b0bf2e90x7617e5d2', 'student_id_pool': '585173', 'id': '47290', 'agg_key': {'Franchesca Belle-McDonald'}}])
# ({'Adler-Radik'}, [{'birth_date_pool': '11/21/2538', 'FIRST_ENTERED_US': '28-NOV-05 12.00.00.000000000 AM', 'first_name_pool': 'Adler', 'gender_pool': 'm', 'last_name_pool': 'Radik', 'middle_name_pool': 'Cylus', 'ssid_pool': '0x2bfd9a3d0x57fb347a', 'student_id_pool': '681752823', 'id': '67791', 'agg_key': {'Adler-Radik'}}])
# ({'Reilly-Moneypenny'}, [{'birth_date_pool': '1/24/1335', 'FIRST_ENTERED_US': '01-APR-92 12.00.00.000000000 AM', 'first_name_pool': 'Reilly', 'gender_pool': 'n', 'last_name_pool': 'Moneypenny', 'middle_name_pool': 'Zakharovich', 'ssid_pool': '0x2e1086b10x5c210d62', 'student_id_pool': '768317', 'id': '70664', 'agg_key': {'Reilly-Moneypenny'}}])
# ({'Thauron-Naumann'}, [{'birth_date_pool': '10/22/2349', 'FIRST_ENTERED_US': '08-AUG-98 12.00.00.000000000 AM', 'first_name_pool': 'Thauron', 'gender_pool': 'n', 'last_name_pool': 'Naumann', 'middle_name_pool': 'Stihl', 'ssid_pool': '0x29b606710x536c0ce2', 'student_id_pool': '956717', 'id': '15100', 'agg_key': {'Thauron-Naumann'}}])
# ({'Wylie-Schweitzer'}, [{'birth_date_pool': '4/7/1343', 'FIRST_ENTERED_US': '14-JUN-05 12.00.00.000000000 AM', 'first_name_pool': 'Wylie', 'gender_pool': 'f', 'last_name_pool': 'Schweitzer', 'middle_name_pool': 'Shadd', 'ssid_pool': '0x1e6cf5df0x3cd9ebbe', 'student_id_pool': '571059', 'id': '108048', 'agg_key': {'Wylie-Schweitzer'}}])
# ({'Aalauhna-Zieseniss'}, [{'birth_date_pool': '6/12/2518', 'FIRST_ENTERED_US': '15-AUG-11 12.00.00.000000000 AM', 'first_name_pool': 'Aalauhna', 'gender_pool': 'n', 'last_name_pool': 'Zieseniss', 'middle_name_pool': 'Gardner', 'ssid_pool': '0x294b543f0x5296a87e', 'student_id_pool': '652265', 'id': '26750', 'agg_key': {'Aalauhna-Zieseniss'}}])
# ({'Spear-Corrales Alvarez'}, [{'birth_date_pool': '10/27/2698', 'FIRST_ENTERED_US': '22-NOV-13 12.00.00.000000000 AM', 'first_name_pool': 'Spear', 'gender_pool': 'm', 'last_name_pool': 'Corrales Alvarez', 'middle_name_pool': 'Elaine Nicole', 'ssid_pool': '0x1f0579320x3e0af264', 'student_id_pool': '305727', 'id': '97636', 'agg_key': {'Spear-Corrales Alvarez'}}])
# ({'Ransom-Stoutsenberger'}, [{'birth_date_pool': '6/22/2535', 'FIRST_ENTERED_US': '25-JUL-95 12.00.00.000000000 AM', 'first_name_pool': 'Ransom', 'gender_pool': 'f', 'last_name_pool': 'Stoutsenberger', 'middle_name_pool': 'Radlee', 'ssid_pool': '0x1dcd12770x3b9a24ee', 'student_id_pool': '634454', 'id': '54286', 'agg_key': {'Ransom-Stoutsenberger'}}])
# ({'Ithzel-Praveenkumar'}, [{'birth_date_pool': '8/17/1532', 'FIRST_ENTERED_US': '14-JUN-96 12.00.00.000000000 AM', 'first_name_pool': 'Ithzel', 'gender_pool': 'f', 'last_name_pool': 'Praveenkumar', 'middle_name_pool': 'Tomoki', 'ssid_pool': '0xc12d3550x1825a6aa', 'student_id_pool': '292309', 'id': '15672', 'agg_key': {'Ithzel-Praveenkumar'}}])
# ({'Ean-Hoda'}, [{'birth_date_pool': '11/19/1743', 'FIRST_ENTERED_US': '01-APR-05 12.00.00.000000000 AM', 'first_name_pool': 'Ean', 'gender_pool': 'f', 'last_name_pool': 'Hoda', 'middle_name_pool': 'Conlin', 'ssid_pool': '0x8df8fd20x11bf1fa4', 'student_id_pool': '232139569', 'id': '123896', 'agg_key': {'Ean-Hoda'}}])
# ({'Kaleio-Fleszar-Ball'}, [{'birth_date_pool': '6/15/1580', 'FIRST_ENTERED_US': '06-JUN-89 12.00.00.000000000 AM', 'first_name_pool': 'Kaleio', 'gender_pool': 'm', 'last_name_pool': 'Fleszar-Ball', 'middle_name_pool': 'Mackenzi', 'ssid_pool': '0x355486240x6aa90c48', 'student_id_pool': '414321', 'id': '50730', 'agg_key': {'Kaleio-Fleszar-Ball'}}])
# ({'Avea-Fogarty'}, [{'birth_date_pool': '2/11/2986', 'FIRST_ENTERED_US': '11-NOV-02 12.00.00.000000000 AM', 'first_name_pool': 'Avea', 'gender_pool': 'n', 'last_name_pool': 'Fogarty', 'middle_name_pool': 'Abdulrazzaq', 'ssid_pool': '0x2a396fdf0x5472dfbe', 'student_id_pool': '601729', 'id': '103427', 'agg_key': {'Avea-Fogarty'}}])
# ({'Loyalty-Mughadi'}, [{'birth_date_pool': '10/17/1613', 'FIRST_ENTERED_US': '01-JAN-96 12.00.00.000000000 AM', 'first_name_pool': 'Loyalty', 'gender_pool': 'm', 'last_name_pool': 'Mughadi', 'middle_name_pool': 'Veda', 'ssid_pool': '0x365397bb0x6ca72f76', 'student_id_pool': '6666355', 'id': '32013', 'agg_key': {'Loyalty-Mughadi'}}])
# ({'Timon-Givens'}, [{'birth_date_pool': '8/10/1948', 'FIRST_ENTERED_US': '22-MAR-07 12.00.00.000000000 AM', 'first_name_pool': 'Timon', 'gender_pool': 'f', 'last_name_pool': 'Givens', 'middle_name_pool': 'Merci', 'ssid_pool': '0x2fea10b30x5fd42166', 'student_id_pool': '922132', 'id': '45045', 'agg_key': {'Timon-Givens'}}])
# ({'Tevyn-Chichoni'}, [{'birth_date_pool': '11/1/1989', 'FIRST_ENTERED_US': '01-APR-99 12.00.00.000000000 AM', 'first_name_pool': 'Tevyn', 'gender_pool': 'n', 'last_name_pool': 'Chichoni', 'middle_name_pool': 'Alexander Jibrael', 'ssid_pool': '0xc8071bc0x1900e378', 'student_id_pool': '713105', 'id': '86774', 'agg_key': {'Tevyn-Chichoni'}}])
# ({"A'zlynn-Zavala Corrales"}, [{'birth_date_pool': '6/22/2831', 'FIRST_ENTERED_US': '30-JAN-03 12.00.00.000000000 AM', 'first_name_pool': "A'zlynn", 'gender_pool': 'n', 'last_name_pool': 'Zavala Corrales', 'middle_name_pool': 'Jonas', 'ssid_pool': '0x1bcea00b0x379d4016', 'student_id_pool': '788630597', 'id': '25798', 'agg_key': {"A'zlynn-Zavala Corrales"}}])
# ({'Nyagaw-Leavitt'}, [{'birth_date_pool': '7/22/2695', 'FIRST_ENTERED_US': '28-AUG-01 12.00.00.000000000 AM', 'first_name_pool': 'Nyagaw', 'gender_pool': 'n', 'last_name_pool': 'Leavitt', 'middle_name_pool': 'Dimee', 'ssid_pool': '0x30b330190x61666032', 'student_id_pool': '975071', 'id': '133564', 'agg_key': {'Nyagaw-Leavitt'}}])
# ({'DaJonna-Juarez Lopez'}, [{'birth_date_pool': '10/27/2338', 'FIRST_ENTERED_US': '29-SEP-10 12.00.00.000000000 AM', 'first_name_pool': 'DaJonna', 'gender_pool': 'm', 'last_name_pool': 'Juarez Lopez', 'middle_name_pool': 'Timmy', 'ssid_pool': '0xb2a8ad10x165515a2', 'student_id_pool': '884468', 'id': '119288', 'agg_key': {'DaJonna-Juarez Lopez'}}])
# ({'Braxlee-Passey'}, [{'birth_date_pool': '9/26/2846', 'FIRST_ENTERED_US': '26-SEP-12 12.00.00.000000000 AM', 'first_name_pool': 'Braxlee', 'gender_pool': 'f', 'last_name_pool': 'Passey', 'middle_name_pool': 'Roc', 'ssid_pool': '0x169d76b10x2d3aed62', 'student_id_pool': '922218', 'id': '114903', 'agg_key': {'Braxlee-Passey'}}])
# ({'Christopher Axle-Antigua'}, [{'birth_date_pool': '5/5/2949', 'FIRST_ENTERED_US': '17-SEP-12 12.00.00.000000000 AM', 'first_name_pool': 'Christopher Axle', 'gender_pool': 'm', 'last_name_pool': 'Antigua', 'middle_name_pool': 'Lorie', 'ssid_pool': '0x1669b6f10x2cd36de2', 'student_id_pool': '727552', 'id': '31771', 'agg_key': {'Christopher Axle-Antigua'}}])
# ({'Zavenda-Montilla Briseno'}, [{'birth_date_pool': '4/26/2884', 'FIRST_ENTERED_US': '25-SEP-15 12.00.00.000000000 AM', 'first_name_pool': 'Zavenda', 'gender_pool': 'f', 'last_name_pool': 'Montilla Briseno', 'middle_name_pool': 'Alayna', 'ssid_pool': '0x6df64400xdbec880', 'student_id_pool': '993836', 'id': '136389', 'agg_key': {'Zavenda-Montilla Briseno'}}])
# ({'Marce-Kranendonk'}, [{'birth_date_pool': '8/13/2376', 'FIRST_ENTERED_US': '04-MAR-91 12.00.00.000000000 AM', 'first_name_pool': 'Marce', 'gender_pool': 'm', 'last_name_pool': 'Kranendonk', 'middle_name_pool': 'Malachi', 'ssid_pool': '0x36105cd70x6c20b9ae', 'student_id_pool': '847943', 'id': '79318', 'agg_key': {'Marce-Kranendonk'}}])
# ({'Braylin-Hidalgo'}, [{'birth_date_pool': '7/26/2032', 'FIRST_ENTERED_US': '07-JAN-04 12.00.00.000000000 AM', 'first_name_pool': 'Braylin', 'gender_pool': 'f', 'last_name_pool': 'Hidalgo', 'middle_name_pool': 'Semisi', 'ssid_pool': '0xdfdb1750x1bfb62ea', 'student_id_pool': '437463', 'id': '22216', 'agg_key': {'Braylin-Hidalgo'}}])
# ({'Swazey-Soukup'}, [{'birth_date_pool': '10/27/2921', 'FIRST_ENTERED_US': '05-APR-10 12.00.00.000000000 AM', 'first_name_pool': 'Swazey', 'gender_pool': 'm', 'last_name_pool': 'Soukup', 'middle_name_pool': 'Ari', 'ssid_pool': '0x1438614c0x2870c298', 'student_id_pool': '503979', 'id': '54795', 'agg_key': {'Swazey-Soukup'}}])
# ({'Tayzen-Coho'}, [{'birth_date_pool': '6/12/2176', 'FIRST_ENTERED_US': '20-AUG-03 12.00.00.000000000 AM', 'first_name_pool': 'Tayzen', 'gender_pool': 'n', 'last_name_pool': 'Coho', 'middle_name_pool': 'Libertad', 'ssid_pool': '0x2a20879e0x54410f3c', 'student_id_pool': '755575', 'id': '109960', 'agg_key': {'Tayzen-Coho'}}])
# ({'Kinnley-Dishong'}, [{'birth_date_pool': '5/25/1552', 'FIRST_ENTERED_US': '26-AUG-04 12.00.00.000000000 AM', 'first_name_pool': 'Kinnley', 'gender_pool': 'm', 'last_name_pool': 'Dishong', 'middle_name_pool': 'Mariee Alexis', 'ssid_pool': '0x2553e95c0x4aa7d2b8', 'student_id_pool': '738824', 'id': '48963', 'agg_key': {'Kinnley-Dishong'}}])
# ({'Coltrick-Maki'}, [{'birth_date_pool': '2/22/2098', 'FIRST_ENTERED_US': '01-MAY-07 12.00.00.000000000 AM', 'first_name_pool': 'Coltrick', 'gender_pool': 'f', 'last_name_pool': 'Maki', 'middle_name_pool': 'Michael Kane', 'ssid_pool': '0x294d27770x529a4eee', 'student_id_pool': '939704836', 'id': '136475', 'agg_key': {'Coltrick-Maki'}}])
# ({'Teihana-Lazo-Hernandez'}, [{'birth_date_pool': '9/25/2472', 'FIRST_ENTERED_US': '21-JUN-17 12.00.00.000000000 AM', 'first_name_pool': 'Teihana', 'gender_pool': 'f', 'last_name_pool': 'Lazo-Hernandez', 'middle_name_pool': 'F', 'ssid_pool': '0x305d03240x60ba0648', 'student_id_pool': '517952', 'id': '136070', 'agg_key': {'Teihana-Lazo-Hernandez'}}])
# ({'Landon-Cardenas-Ledezma'}, [{'birth_date_pool': '10/9/1779', 'FIRST_ENTERED_US': '22-APR-05 12.00.00.000000000 AM', 'first_name_pool': 'Landon', 'gender_pool': 'f', 'last_name_pool': 'Cardenas-Ledezma', 'middle_name_pool': 'Ashkii', 'ssid_pool': '0x2f9d1da10x5f3a3b42', 'student_id_pool': '957022', 'id': '100916', 'agg_key': {'Landon-Cardenas-Ledezma'}}])
# ({'Amarah-Rodriguez Bido'}, [{'birth_date_pool': '1/2/2677', 'FIRST_ENTERED_US': '01-AUG-11 12.00.00.000000000 AM', 'first_name_pool': 'Amarah', 'gender_pool': 'm', 'last_name_pool': 'Rodriguez Bido', 'middle_name_pool': 'Brittany', 'ssid_pool': '0x2c72985a0x58e530b4', 'student_id_pool': '534257', 'id': '73663', 'agg_key': {'Amarah-Rodriguez Bido'}}])
# ({'Elimar-Frette'}, [{'birth_date_pool': '4/10/2782', 'FIRST_ENTERED_US': '23-AUG-94 12.00.00.000000000 AM', 'first_name_pool': 'Elimar', 'gender_pool': 'f', 'last_name_pool': 'Frette', 'middle_name_pool': 'Tetsubo', 'ssid_pool': '0xf109d260x1e213a4c', 'student_id_pool': '621516', 'id': '39087', 'agg_key': {'Elimar-Frette'}}])
# ({'Treigh-Enochs'}, [{'birth_date_pool': '5/1/1757', 'FIRST_ENTERED_US': '14-JUL-15 12.00.00.000000000 AM', 'first_name_pool': 'Treigh', 'gender_pool': 'f', 'last_name_pool': 'Enochs', 'middle_name_pool': 'Jacalene', 'ssid_pool': '0x16d169b70x2da2d36e', 'student_id_pool': '988502', 'id': '45585', 'agg_key': {'Treigh-Enochs'}}])
# ({'Camryn-Gameren'}, [{'birth_date_pool': '7/10/1944', 'FIRST_ENTERED_US': '01-APR-04 12.00.00.000000000 AM', 'first_name_pool': 'Camryn', 'gender_pool': 'n', 'last_name_pool': 'Gameren', 'middle_name_pool': 'Addyline', 'ssid_pool': '0x16231fa50x2c463f4a', 'student_id_pool': '424244', 'id': '6984', 'agg_key': {'Camryn-Gameren'}}])
# ({'Kentley-Gillum'}, [{'birth_date_pool': '1/19/1241', 'FIRST_ENTERED_US': '03-SEP-03 12.00.00.000000000 AM', 'first_name_pool': 'Kentley', 'gender_pool': 'n', 'last_name_pool': 'Gillum', 'middle_name_pool': 'Marston', 'ssid_pool': '0x36ec67ab0x6dd8cf56', 'student_id_pool': '728138', 'id': '116130', 'agg_key': {'Kentley-Gillum'}}])
# ({'Adair-Ahlin'}, [{'birth_date_pool': '2/21/1725', 'FIRST_ENTERED_US': '27-SEP-01 12.00.00.000000000 AM', 'first_name_pool': 'Adair', 'gender_pool': 'f', 'last_name_pool': 'Ahlin', 'middle_name_pool': 'Joleen', 'ssid_pool': '0x816631a0x102cc634', 'student_id_pool': '593738', 'id': '1930', 'agg_key': {'Adair-Ahlin'}}])
# ({'Jaed-Monell'}, [{'birth_date_pool': '2/14/1847', 'FIRST_ENTERED_US': '25-MAY-00 12.00.00.000000000 AM', 'first_name_pool': 'Jaed', 'gender_pool': 'm', 'last_name_pool': 'Monell', 'middle_name_pool': 'Hyrum', 'ssid_pool': '0x2525182d0x4a4a305a', 'student_id_pool': '998679939', 'id': '9722', 'agg_key': {'Jaed-Monell'}}])
# ({'RickyRay-Gibson-Caudle'}, [{'birth_date_pool': '10/19/2156', 'FIRST_ENTERED_US': '23-AUG-00 12.00.00.000000000 AM', 'first_name_pool': 'RickyRay', 'gender_pool': 'n', 'last_name_pool': 'Gibson-Caudle', 'middle_name_pool': 'Chuck', 'ssid_pool': '0x35f3ace30x6be759c6', 'student_id_pool': '423177111', 'id': '73406', 'agg_key': {'RickyRay-Gibson-Caudle'}}])
# ({'Nkemdirim-Yaskov'}, [{'birth_date_pool': '11/3/2784', 'FIRST_ENTERED_US': '01-JAN-17 12.00.00.000000000 AM', 'first_name_pool': 'Nkemdirim', 'gender_pool': 'm', 'last_name_pool': 'Yaskov', 'middle_name_pool': 'Wei', 'ssid_pool': '0x76765e10xececbc2', 'student_id_pool': '839634', 'id': '93466', 'agg_key': {'Nkemdirim-Yaskov'}}])
# ({'Quinnten-Hillin'}, [{'birth_date_pool': '10/13/2649', 'FIRST_ENTERED_US': '16-FEB-05 12.00.00.000000000 AM', 'first_name_pool': 'Quinnten', 'gender_pool': 'm', 'last_name_pool': 'Hillin', 'middle_name_pool': 'Georgia Lavinia', 'ssid_pool': '0x2940242d0x5280485a', 'student_id_pool': '899139755', 'id': '77040', 'agg_key': {'Quinnten-Hillin'}}])
# ({'Meletaiana-Rougeau'}, [{'birth_date_pool': '5/23/2162', 'FIRST_ENTERED_US': '24-SEP-04 12.00.00.000000000 AM', 'first_name_pool': 'Meletaiana', 'gender_pool': 'f', 'last_name_pool': 'Rougeau', 'middle_name_pool': 'Jacob Jaxon', 'ssid_pool': '0x3a8f866a0x751f0cd4', 'student_id_pool': '862925', 'id': '95199', 'agg_key': {'Meletaiana-Rougeau'}}])
# ({'Kaysia-Morales Gonzales'}, [{'birth_date_pool': '7/24/2721', 'FIRST_ENTERED_US': '29-AUG-94 12.00.00.000000000 AM', 'first_name_pool': 'Kaysia', 'gender_pool': 'm', 'last_name_pool': 'Morales Gonzales', 'middle_name_pool': 'Alta Loraine', 'ssid_pool': '0xf430b5c0x1e8616b8', 'student_id_pool': '913628', 'id': '147418', 'agg_key': {'Kaysia-Morales Gonzales'}}])
# ({'Huntington-Garcia-Rivera'}, [{'birth_date_pool': '7/19/1622', 'FIRST_ENTERED_US': '15-APR-05 12.00.00.000000000 AM', 'first_name_pool': 'Huntington', 'gender_pool': 'm', 'last_name_pool': 'Garcia-Rivera', 'middle_name_pool': 'James Kirk', 'ssid_pool': '0x10a544e30x214a89c6', 'student_id_pool': '364259', 'id': '40030', 'agg_key': {'Huntington-Garcia-Rivera'}}])
# ({'Savino-Everson'}, [{'birth_date_pool': '3/16/2166', 'FIRST_ENTERED_US': '30-SEP-89 12.00.00.000000000 AM', 'first_name_pool': 'Savino', 'gender_pool': 'n', 'last_name_pool': 'Everson', 'middle_name_pool': 'Barnabas', 'ssid_pool': '0x114aa7c30x22954f86', 'student_id_pool': '298345', 'id': '41707', 'agg_key': {'Savino-Everson'}}])
# ({'Auni-Heckman'}, [{'birth_date_pool': '8/24/1278', 'FIRST_ENTERED_US': '13-AUG-16 12.00.00.000000000 AM', 'first_name_pool': 'Auni', 'gender_pool': 'f', 'last_name_pool': 'Heckman', 'middle_name_pool': 'Tikona', 'ssid_pool': '0x324e37a20x649c6f44', 'student_id_pool': '986819', 'id': '78918', 'agg_key': {'Auni-Heckman'}}])
# ({'Antjuan-Fredrickson'}, [{'birth_date_pool': '3/14/2274', 'FIRST_ENTERED_US': '15-AUG-16 12.00.00.000000000 AM', 'first_name_pool': 'Antjuan', 'gender_pool': 'f', 'last_name_pool': 'Fredrickson', 'middle_name_pool': 'Thanos', 'ssid_pool': '0x1333f6940x2667ed28', 'student_id_pool': '816636', 'id': '110495', 'agg_key': {'Antjuan-Fredrickson'}}])
# ({'Vanbiak-Woodhead'}, [{'birth_date_pool': '8/4/1322', 'FIRST_ENTERED_US': '04-JUN-07 12.00.00.000000000 AM', 'first_name_pool': 'Vanbiak', 'gender_pool': 'f', 'last_name_pool': 'Woodhead', 'middle_name_pool': 'Shurtleff-Hatch', 'ssid_pool': '0x1319aa640x263354c8', 'student_id_pool': '469941', 'id': '104338', 'agg_key': {'Vanbiak-Woodhead'}}])
# ({'Havyn-Reilly'}, [{'birth_date_pool': '4/7/1734', 'FIRST_ENTERED_US': '11-SEP-08 12.00.00.000000000 AM', 'first_name_pool': 'Havyn', 'gender_pool': 'f', 'last_name_pool': 'Reilly', 'middle_name_pool': 'Griselda', 'ssid_pool': '0x1d0e7d540x3a1cfaa8', 'student_id_pool': '919593', 'id': '118956', 'agg_key': {'Havyn-Reilly'}}])
# ({'Gerardo Arturo-Christian'}, [{'birth_date_pool': '4/26/2779', 'FIRST_ENTERED_US': '23-MAR-96 12.00.00.000000000 AM', 'first_name_pool': 'Gerardo Arturo', 'gender_pool': 'm', 'last_name_pool': 'Christian', 'middle_name_pool': 'LiliulnaUaAoaoina Doreen', 'ssid_pool': '0xa4654a20x148ca944', 'student_id_pool': '36055688', 'id': '147103', 'agg_key': {'Gerardo Arturo-Christian'}}])
# ({'Addysen-London'}, [{'birth_date_pool': '6/1/2242', 'FIRST_ENTERED_US': '05-JAN-15 12.00.00.000000000 AM', 'first_name_pool': 'Addysen', 'gender_pool': 'n', 'last_name_pool': 'London', 'middle_name_pool': 'Michael Kruz', 'ssid_pool': '0x230b30db0x461661b6', 'student_id_pool': '248821', 'id': '43039', 'agg_key': {'Addysen-London'}}])
# ({'Pita-Natividad'}, [{'birth_date_pool': '1/19/2499', 'FIRST_ENTERED_US': '08-AUG-98 12.00.00.000000000 AM', 'first_name_pool': 'Pita', 'gender_pool': 'n', 'last_name_pool': 'Natividad', 'middle_name_pool': 'Brek', 'ssid_pool': '0x383a27b80x70744f70', 'student_id_pool': '440845', 'id': '115758', 'agg_key': {'Pita-Natividad'}}])
# ({'Aisa-Moffat Martinez'}, [{'birth_date_pool': '5/4/2121', 'FIRST_ENTERED_US': '11-NOV-95 12.00.00.000000000 AM', 'first_name_pool': 'Aisa', 'gender_pool': 'f', 'last_name_pool': 'Moffat Martinez', 'middle_name_pool': 'Doyle', 'ssid_pool': '0x10baff890x2175ff12', 'student_id_pool': '744703507', 'id': '73672', 'agg_key': {'Aisa-Moffat Martinez'}}])
# ({'Lorraine-Feragen Lopez'}, [{'birth_date_pool': '11/22/1438', 'FIRST_ENTERED_US': '21-NOV-16 12.00.00.000000000 AM', 'first_name_pool': 'Lorraine', 'gender_pool': 'f', 'last_name_pool': 'Feragen Lopez', 'middle_name_pool': 'LeeRyenne', 'ssid_pool': '0x14ab973d0x29572e7a', 'student_id_pool': '522291', 'id': '44414', 'agg_key': {'Lorraine-Feragen Lopez'}}])
# ({'LylaRae-Donjuan'}, [{'birth_date_pool': '9/10/1699', 'FIRST_ENTERED_US': '26-SEP-06 12.00.00.000000000 AM', 'first_name_pool': 'LylaRae', 'gender_pool': 'm', 'last_name_pool': 'Donjuan', 'middle_name_pool': 'Grace Faith', 'ssid_pool': '0x234758ce0x468eb19c', 'student_id_pool': '642866', 'id': '53002', 'agg_key': {'LylaRae-Donjuan'}}])
# ({'Naleah-Underly'}, [{'birth_date_pool': '4/2/2177', 'FIRST_ENTERED_US': '06-APR-06 12.00.00.000000000 AM', 'first_name_pool': 'Naleah', 'gender_pool': 'n', 'last_name_pool': 'Underly', 'middle_name_pool': 'Wolsey', 'ssid_pool': '0x1656885a0x2cad10b4', 'student_id_pool': '803121', 'id': '130223', 'agg_key': {'Naleah-Underly'}}])
# ({'Danya-Dozudic'}, [{'birth_date_pool': '2/19/1390', 'FIRST_ENTERED_US': '28-MAY-03 12.00.00.000000000 AM', 'first_name_pool': 'Danya', 'gender_pool': 'f', 'last_name_pool': 'Dozudic', 'middle_name_pool': 'Hauser', 'ssid_pool': '0x2c2dd1660x585ba2cc', 'student_id_pool': '328916', 'id': '120332', 'agg_key': {'Danya-Dozudic'}}])
# ({'Kahaya-Reynaga Garcia'}, [{'birth_date_pool': '2/27/1700', 'FIRST_ENTERED_US': '13-JAN-15 12.00.00.000000000 AM', 'first_name_pool': 'Kahaya', 'gender_pool': 'f', 'last_name_pool': 'Reynaga Garcia', 'middle_name_pool': 'Blu', 'ssid_pool': '0x382c6d510x7058daa2', 'student_id_pool': '449370', 'id': '24605', 'agg_key': {'Kahaya-Reynaga Garcia'}}])
# ({'Kavan-Burdakova'}, [{'birth_date_pool': '9/4/1976', 'FIRST_ENTERED_US': '23-JAN-06 12.00.00.000000000 AM', 'first_name_pool': 'Kavan', 'gender_pool': 'n', 'last_name_pool': 'Burdakova', 'middle_name_pool': 'Ahmednur', 'ssid_pool': '0x764e8b60xec9d16c', 'student_id_pool': '630148811', 'id': '76371', 'agg_key': {'Kavan-Burdakova'}}])
# ({'Jadiel-Mercado Montiel'}, [{'birth_date_pool': '2/24/1957', 'FIRST_ENTERED_US': '22-AUG-16 12.00.00.000000000 AM', 'first_name_pool': 'Jadiel', 'gender_pool': 'f', 'last_name_pool': 'Mercado Montiel', 'middle_name_pool': 'Arrington', 'ssid_pool': '0x118b190f0x2316321e', 'student_id_pool': '414014', 'id': '47672', 'agg_key': {'Jadiel-Mercado Montiel'}}])
# ({'Ephriam-Casas'}, [{'birth_date_pool': '11/18/2547', 'FIRST_ENTERED_US': '24-MAY-87 12.00.00.000000000 AM', 'first_name_pool': 'Ephriam', 'gender_pool': 'm', 'last_name_pool': 'Casas', 'middle_name_pool': 'Lilyani Faith', 'ssid_pool': '0x73677db0xe6cefb6', 'student_id_pool': '265177', 'id': '122912', 'agg_key': {'Ephriam-Casas'}}])
# ({'Veleveni-Johannessen'}, [{'birth_date_pool': '9/19/2430', 'FIRST_ENTERED_US': '05-OCT-88 12.00.00.000000000 AM', 'first_name_pool': 'Veleveni', 'gender_pool': 'm', 'last_name_pool': 'Johannessen', 'middle_name_pool': "Tu'imeleke", 'ssid_pool': '0x1019fca90x2033f952', 'student_id_pool': '490564', 'id': '9124', 'agg_key': {'Veleveni-Johannessen'}}])
# ({'Emony Marie-Fiscus'}, [{'birth_date_pool': '11/18/1471', 'FIRST_ENTERED_US': '01-JUL-88 12.00.00.000000000 AM', 'first_name_pool': 'Emony Marie', 'gender_pool': 'm', 'last_name_pool': 'Fiscus', 'middle_name_pool': 'Anna Mae', 'ssid_pool': '0x1c2f65320x385eca64', 'student_id_pool': '780274', 'id': '110398', 'agg_key': {'Emony Marie-Fiscus'}}])
# ({'Oshynn-Wenzel'}, [{'birth_date_pool': '9/9/1663', 'FIRST_ENTERED_US': '28-FEB-01 12.00.00.000000000 AM', 'first_name_pool': 'Oshynn', 'gender_pool': 'n', 'last_name_pool': 'Wenzel', 'middle_name_pool': 'Kera', 'ssid_pool': '0xb3117870x16622f0e', 'student_id_pool': '755559', 'id': '138331', 'agg_key': {'Oshynn-Wenzel'}}])
# ({'Devynn-Funez'}, [{'birth_date_pool': '6/25/1271', 'FIRST_ENTERED_US': '09-JAN-06 12.00.00.000000000 AM', 'first_name_pool': 'Devynn', 'gender_pool': 'n', 'last_name_pool': 'Funez', 'middle_name_pool': 'Brynlee', 'ssid_pool': '0x1868f3dc0x30d1e7b8', 'student_id_pool': '333792', 'id': '140333', 'agg_key': {'Devynn-Funez'}}])
# ({'Tava-Quiggle'}, [{'birth_date_pool': '7/7/1995', 'FIRST_ENTERED_US': '01-FEB-04 12.00.00.000000000 AM', 'first_name_pool': 'Tava', 'gender_pool': 'm', 'last_name_pool': 'Quiggle', 'middle_name_pool': 'Clyde Lee', 'ssid_pool': '0x2f6b73880x5ed6e710', 'student_id_pool': '890952', 'id': '140944', 'agg_key': {'Tava-Quiggle'}}])
# ({'Hazlim-Belnap'}, [{'birth_date_pool': '1/4/1261', 'FIRST_ENTERED_US': '25-DEC-04 12.00.00.000000000 AM', 'first_name_pool': 'Hazlim', 'gender_pool': 'm', 'last_name_pool': 'Belnap', 'middle_name_pool': 'Hollister', 'ssid_pool': '0x2e3166cc0x5c62cd98', 'student_id_pool': '898177', 'id': '50640', 'agg_key': {'Hazlim-Belnap'}}])
# ({'Cassie-Valdez Molina'}, [{'birth_date_pool': '11/5/1968', 'FIRST_ENTERED_US': '07-OCT-14 12.00.00.000000000 AM', 'first_name_pool': 'Cassie', 'gender_pool': 'f', 'last_name_pool': 'Valdez Molina', 'middle_name_pool': 'Artemio', 'ssid_pool': '0x1a5e53f40x34bca7e8', 'student_id_pool': '911463', 'id': '100358', 'agg_key': {'Cassie-Valdez Molina'}}])
# ({'Elly-Posch'}, [{'birth_date_pool': '2/16/1895', 'FIRST_ENTERED_US': '28-SEP-95 12.00.00.000000000 AM', 'first_name_pool': 'Elly', 'gender_pool': 'n', 'last_name_pool': 'Posch', 'middle_name_pool': 'Jence', 'ssid_pool': '0x13698fe20x26d31fc4', 'student_id_pool': '329517', 'id': '54967', 'agg_key': {'Elly-Posch'}}])
# ({'Meshari-Bollinger'}, [{'birth_date_pool': '4/25/1737', 'FIRST_ENTERED_US': '06-SEP-07 12.00.00.000000000 AM', 'first_name_pool': 'Meshari', 'gender_pool': 'm', 'last_name_pool': 'Bollinger', 'middle_name_pool': 'Michiru', 'ssid_pool': '0x292d01f30x525a03e6', 'student_id_pool': '583081', 'id': '82183', 'agg_key': {'Meshari-Bollinger'}}])
# ({'Atira-Gussler'}, [{'birth_date_pool': '8/24/2754', 'FIRST_ENTERED_US': '10-AUG-01 12.00.00.000000000 AM', 'first_name_pool': 'Atira', 'gender_pool': 'f', 'last_name_pool': 'Gussler', 'middle_name_pool': 'ElRay', 'ssid_pool': '0xbf1cb5b0x17e396b6', 'student_id_pool': '758143', 'id': '74266', 'agg_key': {'Atira-Gussler'}}])
# ({'Grant-Goring'}, [{'birth_date_pool': '7/18/1246', 'FIRST_ENTERED_US': '15-MAR-98 12.00.00.000000000 AM', 'first_name_pool': 'Grant', 'gender_pool': 'n', 'last_name_pool': 'Goring', 'middle_name_pool': "Hashke Bit'ahnii", 'ssid_pool': '0x1575e7f80x2aebcff0', 'student_id_pool': '773998', 'id': '54461', 'agg_key': {'Grant-Goring'}}])
# ({'Maizey-Israelsen'}, [{'birth_date_pool': '11/17/2146', 'FIRST_ENTERED_US': '10-FEB-15 12.00.00.000000000 AM', 'first_name_pool': 'Maizey', 'gender_pool': 'f', 'last_name_pool': 'Israelsen', 'middle_name_pool': 'Zorel', 'ssid_pool': '0x20b4ce950x41699d2a', 'student_id_pool': '411163', 'id': '70663', 'agg_key': {'Maizey-Israelsen'}}])
# ({'Traykin-VanderDoes'}, [{'birth_date_pool': '6/10/1705', 'FIRST_ENTERED_US': '02-JUL-90 12.00.00.000000000 AM', 'first_name_pool': 'Traykin', 'gender_pool': 'm', 'last_name_pool': 'VanderDoes', 'middle_name_pool': 'Salita', 'ssid_pool': '0x2c10bf9d0x58217f3a', 'student_id_pool': '814435', 'id': '116114', 'agg_key': {'Traykin-VanderDoes'}}])
# ({'Laeken-Attinella'}, [{'birth_date_pool': '3/3/1838', 'FIRST_ENTERED_US': '30-JAN-09 12.00.00.000000000 AM', 'first_name_pool': 'Laeken', 'gender_pool': 'n', 'last_name_pool': 'Attinella', 'middle_name_pool': 'Sackett', 'ssid_pool': '0x84a32ee0x109465dc', 'student_id_pool': '904063', 'id': '26372', 'agg_key': {'Laeken-Attinella'}}])
# ({'Whitley-Quero'}, [{'birth_date_pool': '9/19/1526', 'FIRST_ENTERED_US': '04-JAN-99 12.00.00.000000000 AM', 'first_name_pool': 'Whitley', 'gender_pool': 'm', 'last_name_pool': 'Quero', 'middle_name_pool': 'Lael', 'ssid_pool': '0x18e667df0x31cccfbe', 'student_id_pool': '661362', 'id': '149411', 'agg_key': {'Whitley-Quero'}}])
# ({'Tundra-Alvizurez Reyes'}, [{'birth_date_pool': '11/2/2598', 'FIRST_ENTERED_US': '22-FEB-12 12.00.00.000000000 AM', 'first_name_pool': 'Tundra', 'gender_pool': 'm', 'last_name_pool': 'Alvizurez Reyes', 'middle_name_pool': 'Christopher Avery', 'ssid_pool': '0x31cc93ca0x63992794', 'student_id_pool': '408313', 'id': '44227', 'agg_key': {'Tundra-Alvizurez Reyes'}}])
# ({'Rosalynd-Navarrette'}, [{'birth_date_pool': '9/12/2407', 'FIRST_ENTERED_US': '30-JAN-16 12.00.00.000000000 AM', 'first_name_pool': 'Rosalynd', 'gender_pool': 'm', 'last_name_pool': 'Navarrette', 'middle_name_pool': 'Tupou Fonua', 'ssid_pool': '0x31f59dc90x63eb3b92', 'student_id_pool': '531847', 'id': '144667', 'agg_key': {'Rosalynd-Navarrette'}}])
# ({'Aimar-Cryer'}, [{'birth_date_pool': '11/15/2177', 'FIRST_ENTERED_US': '23-JUL-07 12.00.00.000000000 AM', 'first_name_pool': 'Aimar', 'gender_pool': 'n', 'last_name_pool': 'Cryer', 'middle_name_pool': 'George John', 'ssid_pool': '0xc8205ce0x19040b9c', 'student_id_pool': '268711', 'id': '129314', 'agg_key': {'Aimar-Cryer'}}])
# ({'Kazzandra-Gaucin Pulido'}, [{'birth_date_pool': '11/23/2074', 'FIRST_ENTERED_US': '19-SEP-04 12.00.00.000000000 AM', 'first_name_pool': 'Kazzandra', 'gender_pool': 'm', 'last_name_pool': 'Gaucin Pulido', 'middle_name_pool': 'Venkata', 'ssid_pool': '0x20a0457f0x41408afe', 'student_id_pool': '917846', 'id': '121335', 'agg_key': {'Kazzandra-Gaucin Pulido'}}])
# ({'Thayne-Boyle'}, [{'birth_date_pool': '10/3/1623', 'FIRST_ENTERED_US': '02-FEB-02 12.00.00.000000000 AM', 'first_name_pool': 'Thayne', 'gender_pool': 'f', 'last_name_pool': 'Boyle', 'middle_name_pool': 'Kel', 'ssid_pool': '0x18fdcc7f0x31fb98fe', 'student_id_pool': '304588', 'id': '49146', 'agg_key': {'Thayne-Boyle'}}])
# ({'Salad-Mentzer'}, [{'birth_date_pool': '2/23/2925', 'FIRST_ENTERED_US': '10-JUL-98 12.00.00.000000000 AM', 'first_name_pool': 'Salad', 'gender_pool': 'f', 'last_name_pool': 'Mentzer', 'middle_name_pool': 'Suzanna', 'ssid_pool': '0xac558880x158ab110', 'student_id_pool': '960271', 'id': '100750', 'agg_key': {'Salad-Mentzer'}}])
# ({'Darianna-McGarrity'}, [{'birth_date_pool': '2/19/1683', 'FIRST_ENTERED_US': '07-SEP-96 12.00.00.000000000 AM', 'first_name_pool': 'Darianna', 'gender_pool': 'f', 'last_name_pool': 'McGarrity', 'middle_name_pool': 'Eoin', 'ssid_pool': '0x3205e3550x640bc6aa', 'student_id_pool': '429258', 'id': '37179', 'agg_key': {'Darianna-McGarrity'}}])
# ({'Kassian-Bravo Bautista'}, [{'birth_date_pool': '10/21/2233', 'FIRST_ENTERED_US': '31-MAR-98 12.00.00.000000000 AM', 'first_name_pool': 'Kassian', 'gender_pool': 'n', 'last_name_pool': 'Bravo Bautista', 'middle_name_pool': 'Bre', 'ssid_pool': '0x1917ed920x322fdb24', 'student_id_pool': '810539', 'id': '21205', 'agg_key': {'Kassian-Bravo Bautista'}}])
# ({'Nykenlee-Derogon'}, [{'birth_date_pool': '10/17/2155', 'FIRST_ENTERED_US': '01-MAR-01 12.00.00.000000000 AM', 'first_name_pool': 'Nykenlee', 'gender_pool': 'f', 'last_name_pool': 'Derogon', 'middle_name_pool': 'David Westley', 'ssid_pool': '0x1a00450f0x34008a1e', 'student_id_pool': '905904', 'id': '91061', 'agg_key': {'Nykenlee-Derogon'}}])
# ({'Jetta-Camara'}, [{'birth_date_pool': '9/11/1304', 'FIRST_ENTERED_US': '24-SEP-07 12.00.00.000000000 AM', 'first_name_pool': 'Jetta', 'gender_pool': 'm', 'last_name_pool': 'Camara', 'middle_name_pool': 'Antonio Merecce', 'ssid_pool': '0x337e5d8c0x66fcbb18', 'student_id_pool': '805224', 'id': '121302', 'agg_key': {'Jetta-Camara'}}])
# ({'Mahra-Fobian'}, [{'birth_date_pool': '9/27/2564', 'FIRST_ENTERED_US': '28-JUL-97 12.00.00.000000000 AM', 'first_name_pool': 'Mahra', 'gender_pool': 'f', 'last_name_pool': 'Fobian', 'middle_name_pool': 'Margot', 'ssid_pool': '0x120513c00x240a2780', 'student_id_pool': '708050355', 'id': '79546', 'agg_key': {'Mahra-Fobian'}}])
# ({'Lars-Marlar'}, [{'birth_date_pool': '5/17/2244', 'FIRST_ENTERED_US': '16-JAN-91 12.00.00.000000000 AM', 'first_name_pool': 'Lars', 'gender_pool': 'f', 'last_name_pool': 'Marlar', 'middle_name_pool': 'Ann Dawn', 'ssid_pool': '0x2bc5beaa0x578b7d54', 'student_id_pool': '290012', 'id': '97863', 'agg_key': {'Lars-Marlar'}}])
# ({'Arron-Wolz'}, [{'birth_date_pool': '2/18/2831', 'FIRST_ENTERED_US': '31-JAN-04 12.00.00.000000000 AM', 'first_name_pool': 'Arron', 'gender_pool': 'f', 'last_name_pool': 'Wolz', 'middle_name_pool': 'Eventide', 'ssid_pool': '0x1d82ba7c0x3b0574f8', 'student_id_pool': '781568', 'id': '71278', 'agg_key': {'Arron-Wolz'}}])
# ({'Varebojie-Hurley'}, [{'birth_date_pool': '5/20/2983', 'FIRST_ENTERED_US': '30-DEC-95 12.00.00.000000000 AM', 'first_name_pool': 'Varebojie', 'gender_pool': 'm', 'last_name_pool': 'Hurley', 'middle_name_pool': 'James-Walter', 'ssid_pool': '0x22aacf3b0x45559e76', 'student_id_pool': '616550', 'id': '41059', 'agg_key': {'Varebojie-Hurley'}}])
# ({'Jeramie-Kovrigin'}, [{'birth_date_pool': '7/24/1911', 'FIRST_ENTERED_US': '29-AUG-11 12.00.00.000000000 AM', 'first_name_pool': 'Jeramie', 'gender_pool': 'f', 'last_name_pool': 'Kovrigin', 'middle_name_pool': 'Leonaitasi', 'ssid_pool': '0x2e2dd6ce0x5c5bad9c', 'student_id_pool': '389206', 'id': '145853', 'agg_key': {'Jeramie-Kovrigin'}}])
# ({'Kahaan-Beckner'}, [{'birth_date_pool': '1/25/2685', 'FIRST_ENTERED_US': '12-SEP-05 12.00.00.000000000 AM', 'first_name_pool': 'Kahaan', 'gender_pool': 'n', 'last_name_pool': 'Beckner', 'middle_name_pool': 'Bevan', 'ssid_pool': '0x212e03ee0x425c07dc', 'student_id_pool': '436411', 'id': '2329', 'agg_key': {'Kahaan-Beckner'}}])
# ({'Zayah-Westwater'}, [{'birth_date_pool': '9/8/1797', 'FIRST_ENTERED_US': '01-JUN-96 12.00.00.000000000 AM', 'first_name_pool': 'Zayah', 'gender_pool': 'm', 'last_name_pool': 'Westwater', 'middle_name_pool': 'Yekaterina', 'ssid_pool': '0xd36ab680x1a6d56d0', 'student_id_pool': '942469', 'id': '113475', 'agg_key': {'Zayah-Westwater'}}])
# ({'Cecee-Rayas-Valle'}, [{'birth_date_pool': '2/5/2779', 'FIRST_ENTERED_US': '30-OCT-93 12.00.00.000000000 AM', 'first_name_pool': 'Cecee', 'gender_pool': 'f', 'last_name_pool': 'Rayas-Valle', 'middle_name_pool': 'Gregory', 'ssid_pool': '0x2ff9b4f40x5ff369e8', 'student_id_pool': '842942', 'id': '97026', 'agg_key': {'Cecee-Rayas-Valle'}}])
# ({'Patch-Pendleton'}, [{'birth_date_pool': '5/19/2288', 'FIRST_ENTERED_US': '23-AUG-17 12.00.00.000000000 AM', 'first_name_pool': 'Patch', 'gender_pool': 'm', 'last_name_pool': 'Pendleton', 'middle_name_pool': 'Dona', 'ssid_pool': '0xe6648e20x1ccc91c4', 'student_id_pool': '328828', 'id': '11212', 'agg_key': {'Patch-Pendleton'}}])
# ({'Juleon-Bravo Lopez'}, [{'birth_date_pool': '3/20/1812', 'FIRST_ENTERED_US': '28-OCT-02 12.00.00.000000000 AM', 'first_name_pool': 'Juleon', 'gender_pool': 'n', 'last_name_pool': 'Bravo Lopez', 'middle_name_pool': 'Jama', 'ssid_pool': '0x2b8595a20x570b2b44', 'student_id_pool': '863235', 'id': '57496', 'agg_key': {'Juleon-Bravo Lopez'}}])
# ({'Carwynn-Enos'}, [{'birth_date_pool': '8/7/2611', 'FIRST_ENTERED_US': '20-SEP-95 12.00.00.000000000 AM', 'first_name_pool': 'Carwynn', 'gender_pool': 'f', 'last_name_pool': 'Enos', 'middle_name_pool': 'Luray', 'ssid_pool': '0x232c6d950x4658db2a', 'student_id_pool': '729085', 'id': '34418', 'agg_key': {'Carwynn-Enos'}}])
# ({'Leovanny-Vago'}, [{'birth_date_pool': '4/18/1957', 'FIRST_ENTERED_US': '13-MAY-10 12.00.00.000000000 AM', 'first_name_pool': 'Leovanny', 'gender_pool': 'n', 'last_name_pool': 'Vago', 'middle_name_pool': 'Francis-Louise', 'ssid_pool': '0x1f88235d0x3f1046ba', 'student_id_pool': '567496', 'id': '135386', 'agg_key': {'Leovanny-Vago'}}])
# ({'VerolyJean-Wilberg'}, [{'birth_date_pool': '8/3/1337', 'FIRST_ENTERED_US': '11-DEC-13 12.00.00.000000000 AM', 'first_name_pool': 'VerolyJean', 'gender_pool': 'n', 'last_name_pool': 'Wilberg', 'middle_name_pool': 'Tariq', 'ssid_pool': '0x146ea6780x28dd4cf0', 'student_id_pool': '449070', 'id': '92458', 'agg_key': {'VerolyJean-Wilberg'}}])
# ({'Zaydi-Ntshalintshali'}, [{'birth_date_pool': '9/24/1441', 'FIRST_ENTERED_US': '06-SEP-07 12.00.00.000000000 AM', 'first_name_pool': 'Zaydi', 'gender_pool': 'f', 'last_name_pool': 'Ntshalintshali', 'middle_name_pool': 'Yeleni', 'ssid_pool': '0x37cabd500x6f957aa0', 'student_id_pool': '673451', 'id': '83787', 'agg_key': {'Zaydi-Ntshalintshali'}}])
# ({'Tracker-MacCourtney'}, [{'birth_date_pool': '9/4/1496', 'FIRST_ENTERED_US': '15-APR-05 12.00.00.000000000 AM', 'first_name_pool': 'Tracker', 'gender_pool': 'm', 'last_name_pool': 'MacCourtney', 'middle_name_pool': 'Franklin Ray', 'ssid_pool': '0x323643120x646c8624', 'student_id_pool': '915727', 'id': '70076', 'agg_key': {'Tracker-MacCourtney'}}])
# ({'Traeger-Polanco Roman'}, [{'birth_date_pool': '1/15/1534', 'FIRST_ENTERED_US': '02-OCT-06 12.00.00.000000000 AM', 'first_name_pool': 'Traeger', 'gender_pool': 'n', 'last_name_pool': 'Polanco Roman', 'middle_name_pool': 'Seiyee', 'ssid_pool': '0x19b886820x33710d04', 'student_id_pool': '573047937', 'id': '68044', 'agg_key': {'Traeger-Polanco Roman'}}])
# ({'Zaphira-Capello'}, [{'birth_date_pool': '1/3/1277', 'FIRST_ENTERED_US': '13-SEP-16 12.00.00.000000000 AM', 'first_name_pool': 'Zaphira', 'gender_pool': 'm', 'last_name_pool': 'Capello', 'middle_name_pool': 'Mateus de Oliveira', 'ssid_pool': '0x29f2c25b0x53e584b6', 'student_id_pool': '736978', 'id': '130396', 'agg_key': {'Zaphira-Capello'}}])
# ({'Khaleya-Bedont'}, [{'birth_date_pool': '2/2/1481', 'FIRST_ENTERED_US': '23-AUG-95 12.00.00.000000000 AM', 'first_name_pool': 'Khaleya', 'gender_pool': 'f', 'last_name_pool': 'Bedont', 'middle_name_pool': 'Justen', 'ssid_pool': '0x35e3dd200x6bc7ba40', 'student_id_pool': '448600', 'id': '25133', 'agg_key': {'Khaleya-Bedont'}}])
# ({'Juliana-McQuiston'}, [{'birth_date_pool': '8/12/1306', 'FIRST_ENTERED_US': '04-JUN-07 12.00.00.000000000 AM', 'first_name_pool': 'Juliana', 'gender_pool': 'f', 'last_name_pool': 'McQuiston', 'middle_name_pool': 'Alisi', 'ssid_pool': '0x2e89d1fc0x5d13a3f8', 'student_id_pool': '730726984', 'id': '29650', 'agg_key': {'Juliana-McQuiston'}}])
# ({'Vihanshi-Lybbert'}, [{'birth_date_pool': '11/22/1397', 'FIRST_ENTERED_US': '22-AUG-05 12.00.00.000000000 AM', 'first_name_pool': 'Vihanshi', 'gender_pool': 'f', 'last_name_pool': 'Lybbert', 'middle_name_pool': 'Vaaloa', 'ssid_pool': '0x32269dc20x644d3b84', 'student_id_pool': '973368', 'id': '63540', 'agg_key': {'Vihanshi-Lybbert'}}])
# ({"P'Mani-Torman"}, [{'birth_date_pool': '10/22/1563', 'FIRST_ENTERED_US': '13-APR-94 12.00.00.000000000 AM', 'first_name_pool': "P'Mani", 'gender_pool': 'n', 'last_name_pool': 'Torman', 'middle_name_pool': 'J Ruben', 'ssid_pool': '0x21cf26c60x439e4d8c', 'student_id_pool': '464810', 'id': '108531', 'agg_key': {"P'Mani-Torman"}}])
# ({'Mighya-Viereck'}, [{'birth_date_pool': '1/20/1232', 'FIRST_ENTERED_US': '25-DEC-01 12.00.00.000000000 AM', 'first_name_pool': 'Mighya', 'gender_pool': 'f', 'last_name_pool': 'Viereck', 'middle_name_pool': 'Adau Micheal Deng', 'ssid_pool': '0x14b340120x29668024', 'student_id_pool': '122551793', 'id': '92881', 'agg_key': {'Mighya-Viereck'}}])
# ({'Kenedi-Estrada Vasquez'}, [{'birth_date_pool': '7/15/1956', 'FIRST_ENTERED_US': '02-FEB-05 12.00.00.000000000 AM', 'first_name_pool': 'Kenedi', 'gender_pool': 'f', 'last_name_pool': 'Estrada Vasquez', 'middle_name_pool': 'Aristotle', 'ssid_pool': '0x110c95280x22192a50', 'student_id_pool': '303804', 'id': '26440', 'agg_key': {'Kenedi-Estrada Vasquez'}}])
# ({'Yanneiry-Escalona'}, [{'birth_date_pool': '11/19/2380', 'FIRST_ENTERED_US': '22-FEB-12 12.00.00.000000000 AM', 'first_name_pool': 'Yanneiry', 'gender_pool': 'm', 'last_name_pool': 'Escalona', 'middle_name_pool': 'David Chet', 'ssid_pool': '0x2b6e97500x56dd2ea0', 'student_id_pool': '345457', 'id': '23420', 'agg_key': {'Yanneiry-Escalona'}}])
# ({'Brax-Lopez Alatorre'}, [{'birth_date_pool': '11/1/1825', 'FIRST_ENTERED_US': '01-JAN-87 12.00.00.000000000 AM', 'first_name_pool': 'Brax', 'gender_pool': 'm', 'last_name_pool': 'Lopez Alatorre', 'middle_name_pool': 'Magan', 'ssid_pool': '0x2a409b8d0x5481371a', 'student_id_pool': '780138', 'id': '118849', 'agg_key': {'Brax-Lopez Alatorre'}}])
# ({'Geminya-Bekker'}, [{'birth_date_pool': '7/6/2109', 'FIRST_ENTERED_US': '01-JUN-93 12.00.00.000000000 AM', 'first_name_pool': 'Geminya', 'gender_pool': 'm', 'last_name_pool': 'Bekker', 'middle_name_pool': 'Janie', 'ssid_pool': '0x1c79f09b0x38f3e136', 'student_id_pool': '337138', 'id': '85919', 'agg_key': {'Geminya-Bekker'}}])
# ({'Blanche-Malan'}, [{'birth_date_pool': '9/4/1296', 'FIRST_ENTERED_US': '01-SEP-00 12.00.00.000000000 AM', 'first_name_pool': 'Blanche', 'gender_pool': 'f', 'last_name_pool': 'Malan', 'middle_name_pool': 'Dax', 'ssid_pool': '0x1fa33b3d0x3f46767a', 'student_id_pool': '841872', 'id': '60813', 'agg_key': {'Blanche-Malan'}}])
# ({'Ralayah-Nolde'}, [{'birth_date_pool': '9/15/1787', 'FIRST_ENTERED_US': '27-SEP-01 12.00.00.000000000 AM', 'first_name_pool': 'Ralayah', 'gender_pool': 'n', 'last_name_pool': 'Nolde', 'middle_name_pool': 'Eudora', 'ssid_pool': '0x16b4a8b00x2d695160', 'student_id_pool': '812170', 'id': '59184', 'agg_key': {'Ralayah-Nolde'}}])
# ({'Kinslee-Moos'}, [{'birth_date_pool': '10/12/2257', 'FIRST_ENTERED_US': '26-OCT-98 12.00.00.000000000 AM', 'first_name_pool': 'Kinslee', 'gender_pool': 'n', 'last_name_pool': 'Moos', 'middle_name_pool': 'Salomon', 'ssid_pool': '0x3280f21f0x6501e43e', 'student_id_pool': '268646', 'id': '103634', 'agg_key': {'Kinslee-Moos'}}])
# ({'Flash-Furnell'}, [{'birth_date_pool': '4/2/2113', 'FIRST_ENTERED_US': '22-JUL-04 12.00.00.000000000 AM', 'first_name_pool': 'Flash', 'gender_pool': 'm', 'last_name_pool': 'Furnell', 'middle_name_pool': 'Dellya', 'ssid_pool': '0x31f1a5ff0x63e34bfe', 'student_id_pool': '791650', 'id': '27166', 'agg_key': {'Flash-Furnell'}}])
# ({'Cathali-Berman'}, [{'birth_date_pool': '3/17/2589', 'FIRST_ENTERED_US': '02-OCT-07 12.00.00.000000000 AM', 'first_name_pool': 'Cathali', 'gender_pool': 'n', 'last_name_pool': 'Berman', 'middle_name_pool': 'Esther', 'ssid_pool': '0x21997ed20x4332fda4', 'student_id_pool': '438362', 'id': '52443', 'agg_key': {'Cathali-Berman'}}])
# ({'MaKensie-Nacki'}, [{'birth_date_pool': '1/27/2559', 'FIRST_ENTERED_US': '11-NOV-98 12.00.00.000000000 AM', 'first_name_pool': 'MaKensie', 'gender_pool': 'f', 'last_name_pool': 'Nacki', 'middle_name_pool': 'Nelle', 'ssid_pool': '0x3a04bfeb0x74097fd6', 'student_id_pool': '862945', 'id': '126030', 'agg_key': {'MaKensie-Nacki'}}])
# ({'Alleon-Galati'}, [{'birth_date_pool': '6/27/1618', 'FIRST_ENTERED_US': '30-JAN-17 12.00.00.000000000 AM', 'first_name_pool': 'Alleon', 'gender_pool': 'f', 'last_name_pool': 'Galati', 'middle_name_pool': "Litia 'O Saione Lavulo", 'ssid_pool': '0x7b886370xf710c6e', 'student_id_pool': '943122', 'id': '19470', 'agg_key': {'Alleon-Galati'}}])
# ({'Barlow-Cardenas Marroquin'}, [{'birth_date_pool': '7/24/2938', 'FIRST_ENTERED_US': '20-AUG-05 12.00.00.000000000 AM', 'first_name_pool': 'Barlow', 'gender_pool': 'f', 'last_name_pool': 'Cardenas Marroquin', 'middle_name_pool': 'Donna', 'ssid_pool': '0x2c62c9470x58c5928e', 'student_id_pool': '456141', 'id': '82357', 'agg_key': {'Barlow-Cardenas Marroquin'}}])
# ({'Almira-Gaytan Pantoja'}, [{'birth_date_pool': '10/5/1676', 'FIRST_ENTERED_US': '12-AUG-07 12.00.00.000000000 AM', 'first_name_pool': 'Almira', 'gender_pool': 'f', 'last_name_pool': 'Gaytan Pantoja', 'middle_name_pool': 'Mathia', 'ssid_pool': '0x1babbf480x37577e90', 'student_id_pool': '712745', 'id': '5598', 'agg_key': {'Almira-Gaytan Pantoja'}}])
# ({'Princeston-Guerrero Nungaray'}, [{'birth_date_pool': '9/15/1257', 'FIRST_ENTERED_US': '22-NOV-13 12.00.00.000000000 AM', 'first_name_pool': 'Princeston', 'gender_pool': 'n', 'last_name_pool': 'Guerrero Nungaray', 'middle_name_pool': 'Douglas Killian', 'ssid_pool': '0x8eabe540x11d57ca8', 'student_id_pool': '532961', 'id': '71916', 'agg_key': {'Princeston-Guerrero Nungaray'}}])
# ({'Eyberlin-Ille'}, [{'birth_date_pool': '5/17/2987', 'FIRST_ENTERED_US': '06-NOV-09 12.00.00.000000000 AM', 'first_name_pool': 'Eyberlin', 'gender_pool': 'f', 'last_name_pool': 'Ille', 'middle_name_pool': 'Greyeson', 'ssid_pool': '0x3b7b2e4f0x76f65c9e', 'student_id_pool': '346440', 'id': '19', 'agg_key': {'Eyberlin-Ille'}}])
# ({'Christianna-Thresher'}, [{'birth_date_pool': '6/27/1370', 'FIRST_ENTERED_US': '25-SEP-07 12.00.00.000000000 AM', 'first_name_pool': 'Christianna', 'gender_pool': 'f', 'last_name_pool': 'Thresher', 'middle_name_pool': 'Florencia', 'ssid_pool': '0x32f4b4060x65e9680c', 'student_id_pool': '822298199', 'id': '110741', 'agg_key': {'Christianna-Thresher'}}])
# ({'Norma-Padgette'}, [{'birth_date_pool': '5/26/1303', 'FIRST_ENTERED_US': '04-MAY-04 12.00.00.000000000 AM', 'first_name_pool': 'Norma', 'gender_pool': 'n', 'last_name_pool': 'Padgette', 'middle_name_pool': 'Joseph King', 'ssid_pool': '0x1e3061b90x3c60c372', 'student_id_pool': '896675', 'id': '135629', 'agg_key': {'Norma-Padgette'}}])
# ({'Millianna-Cuadras Soto'}, [{'birth_date_pool': '11/19/1993', 'FIRST_ENTERED_US': '30-JAN-95 12.00.00.000000000 AM', 'first_name_pool': 'Millianna', 'gender_pool': 'f', 'last_name_pool': 'Cuadras Soto', 'middle_name_pool': 'Paige Hollis', 'ssid_pool': '0x975328c0x12ea6518', 'student_id_pool': '987024', 'id': '93570', 'agg_key': {'Millianna-Cuadras Soto'}}])
# ({'Stefenn-Radtke'}, [{'birth_date_pool': '4/25/2987', 'FIRST_ENTERED_US': '01-SEP-09 12.00.00.000000000 AM', 'first_name_pool': 'Stefenn', 'gender_pool': 'm', 'last_name_pool': 'Radtke', 'middle_name_pool': 'Mykhailovych', 'ssid_pool': '0x20e08d3c0x41c11a78', 'student_id_pool': '593490', 'id': '38870', 'agg_key': {'Stefenn-Radtke'}}])
# ({'Henele-Halverson'}, [{'birth_date_pool': '1/16/1881', 'FIRST_ENTERED_US': '28-OCT-02 12.00.00.000000000 AM', 'first_name_pool': 'Henele', 'gender_pool': 'n', 'last_name_pool': 'Halverson', 'middle_name_pool': "O'Niel", 'ssid_pool': '0xd9d112c0x1b3a2258', 'student_id_pool': '563357', 'id': '139185', 'agg_key': {'Henele-Halverson'}}])
# ({'Quinncie-Hobbs'}, [{'birth_date_pool': '5/10/2411', 'FIRST_ENTERED_US': '01-JUN-09 12.00.00.000000000 AM', 'first_name_pool': 'Quinncie', 'gender_pool': 'm', 'last_name_pool': 'Hobbs', 'middle_name_pool': 'Menny', 'ssid_pool': '0x22cf8ad20x459f15a4', 'student_id_pool': '977486', 'id': '140186', 'agg_key': {'Quinncie-Hobbs'}}])
# ...
# ({'Elenoa-Reynaga Ocampo'}, [{'birth_date_pool': '10/15/2173', 'FIRST_ENTERED_US': '29-AUG-01 12.00.00.000000000 AM', 'first_name_pool': 'Elenoa', 'gender_pool': 'f', 'last_name_pool': 'Reynaga Ocampo', 'middle_name_pool': 'Vailoa', 'ssid_pool': '0x24e967ef0x49d2cfde', 'student_id_pool': '564286', 'id': '148611', 'agg_key': {'Elenoa-Reynaga Ocampo'}}])
# ({'Graci-Marrero Jimenez'}, [{'birth_date_pool': '7/15/2316', 'FIRST_ENTERED_US': '10-OCT-06 12.00.00.000000000 AM', 'first_name_pool': 'Graci', 'gender_pool': 'n', 'last_name_pool': 'Marrero Jimenez', 'middle_name_pool': 'Blaine Deonne', 'ssid_pool': '0x885324e0x110a649c', 'student_id_pool': '420674', 'id': '44032', 'agg_key': {'Graci-Marrero Jimenez'}}])
# ({'Ena-Jiao'}, [{'birth_date_pool': '9/11/2477', 'FIRST_ENTERED_US': '15-AUG-03 12.00.00.000000000 AM', 'first_name_pool': 'Ena', 'gender_pool': 'f', 'last_name_pool': 'Jiao', 'middle_name_pool': 'Hawk', 'ssid_pool': '0x1fee40cc0x3fdc8198', 'student_id_pool': '438934', 'id': '80483', 'agg_key': {'Ena-Jiao'}}])
# ({'Myreel-Lillian'}, [{'birth_date_pool': '1/15/2637', 'FIRST_ENTERED_US': '19-AUG-14 12.00.00.000000000 AM', 'first_name_pool': 'Myreel', 'gender_pool': 'm', 'last_name_pool': 'Lillian', 'middle_name_pool': "Salumalo Fa'asilitama'ita'i", 'ssid_pool': '0x2ab9746e0x5572e8dc', 'student_id_pool': '229473', 'id': '74759', 'agg_key': {'Myreel-Lillian'}}])
# ({'Jaicy-Velazquez Hernandez'}, [{'birth_date_pool': '4/25/2731', 'FIRST_ENTERED_US': '30-AUG-96 12.00.00.000000000 AM', 'first_name_pool': 'Jaicy', 'gender_pool': 'm', 'last_name_pool': 'Velazquez Hernandez', 'middle_name_pool': 'Kelly Floyd', 'ssid_pool': '0x313093af0x6261275e', 'student_id_pool': '799886', 'id': '72717', 'agg_key': {'Jaicy-Velazquez Hernandez'}}])
# ({'Jayedes-Grigg'}, [{'birth_date_pool': '10/23/2773', 'FIRST_ENTERED_US': '19-APR-04 12.00.00.000000000 AM', 'first_name_pool': 'Jayedes', 'gender_pool': 'f', 'last_name_pool': 'Grigg', 'middle_name_pool': 'Aimee', 'ssid_pool': '0x1c77000f0x38ee001e', 'student_id_pool': '763916', 'id': '80717', 'agg_key': {'Jayedes-Grigg'}}])
# ({'Lukesh-Meza Meza'}, [{'birth_date_pool': '6/15/1791', 'FIRST_ENTERED_US': '26-AUG-02 12.00.00.000000000 AM', 'first_name_pool': 'Lukesh', 'gender_pool': 'n', 'last_name_pool': 'Meza Meza', 'middle_name_pool': 'Domenico', 'ssid_pool': '0x2ee6af410x5dcd5e82', 'student_id_pool': '875806', 'id': '46172', 'agg_key': {'Lukesh-Meza Meza'}}])
# ({"Ka'Layah-Bhurtel"}, [{'birth_date_pool': '4/22/1645', 'FIRST_ENTERED_US': '01-OCT-93 12.00.00.000000000 AM', 'first_name_pool': "Ka'Layah", 'gender_pool': 'n', 'last_name_pool': 'Bhurtel', 'middle_name_pool': "Kaleo'okalani", 'ssid_pool': '0x294b52330x5296a466', 'student_id_pool': '754194775', 'id': '64292', 'agg_key': {"Ka'Layah-Bhurtel"}}])
# ({'Hashim-Tookes'}, [{'birth_date_pool': '7/13/1260', 'FIRST_ENTERED_US': '05-SEP-01 12.00.00.000000000 AM', 'first_name_pool': 'Hashim', 'gender_pool': 'm', 'last_name_pool': 'Tookes', 'middle_name_pool': 'Alex Paakwesi', 'ssid_pool': '0x2cb6bd970x596d7b2e', 'student_id_pool': '455026', 'id': '15783', 'agg_key': {'Hashim-Tookes'}}])
# ({'Anur-Escobar Zamora'}, [{'birth_date_pool': '11/1/2711', 'FIRST_ENTERED_US': '01-JUN-05 12.00.00.000000000 AM', 'first_name_pool': 'Anur', 'gender_pool': 'm', 'last_name_pool': 'Escobar Zamora', 'middle_name_pool': 'Limalau', 'ssid_pool': '0x257fc0220x4aff8044', 'student_id_pool': '911857', 'id': '109468', 'agg_key': {'Anur-Escobar Zamora'}}])
# ({'Abutalib-Kirth'}, [{'birth_date_pool': '3/26/2565', 'FIRST_ENTERED_US': '30-MAR-06 12.00.00.000000000 AM', 'first_name_pool': 'Abutalib', 'gender_pool': 'f', 'last_name_pool': 'Kirth', 'middle_name_pool': 'Dayami', 'ssid_pool': '0x28ce51f60x519ca3ec', 'student_id_pool': '729399312', 'id': '46361', 'agg_key': {'Abutalib-Kirth'}}])
# ({'Klarissa-Rhodes'}, [{'birth_date_pool': '4/5/1702', 'FIRST_ENTERED_US': '02-SEP-97 12.00.00.000000000 AM', 'first_name_pool': 'Klarissa', 'gender_pool': 'n', 'last_name_pool': 'Rhodes', 'middle_name_pool': 'Chantz', 'ssid_pool': '0x2a876cc10x550ed982', 'student_id_pool': '915807', 'id': '69338', 'agg_key': {'Klarissa-Rhodes'}}])
# ({'Nhat Minh-Allshouse'}, [{'birth_date_pool': '2/5/1548', 'FIRST_ENTERED_US': '15-NOV-01 12.00.00.000000000 AM', 'first_name_pool': 'Nhat Minh', 'gender_pool': 'n', 'last_name_pool': 'Allshouse', 'middle_name_pool': 'Meikle', 'ssid_pool': '0x14863c4d0x290c789a', 'student_id_pool': '232700', 'id': '18222', 'agg_key': {'Nhat Minh-Allshouse'}}])
# ({'Victory-Campos Maldonado'}, [{'birth_date_pool': '5/21/2109', 'FIRST_ENTERED_US': '01-JUL-84 12.00.00.000000000 AM', 'first_name_pool': 'Victory', 'gender_pool': 'f', 'last_name_pool': 'Campos Maldonado', 'middle_name_pool': 'Tallen', 'ssid_pool': '0x2d67c2d00x5acf85a0', 'student_id_pool': '462011', 'id': '43040', 'agg_key': {'Victory-Campos Maldonado'}}])
# ({'Daizjyn-Ohuafi'}, [{'birth_date_pool': '7/25/2874', 'FIRST_ENTERED_US': '26-SEP-99 12.00.00.000000000 AM', 'first_name_pool': 'Daizjyn', 'gender_pool': 'n', 'last_name_pool': 'Ohuafi', 'middle_name_pool': 'Connolly', 'ssid_pool': '0x28726abf0x50e4d57e', 'student_id_pool': '579466', 'id': '44139', 'agg_key': {'Daizjyn-Ohuafi'}}])
# ({'Yeimmy-Perez Gutierrez'}, [{'birth_date_pool': '8/25/1863', 'FIRST_ENTERED_US': '', 'first_name_pool': 'Yeimmy', 'gender_pool': 'n', 'last_name_pool': 'Perez Gutierrez', 'middle_name_pool': 'Douglas Kawika', 'ssid_pool': '0x161672f60x2c2ce5ec', 'student_id_pool': '329617', 'id': '143250', 'agg_key': {'Yeimmy-Perez Gutierrez'}}])
# ({'Polokava-Luna Ramirez'}, [{'birth_date_pool': '11/9/2708', 'FIRST_ENTERED_US': '15-AUG-11 12.00.00.000000000 AM', 'first_name_pool': 'Polokava', 'gender_pool': 'm', 'last_name_pool': 'Luna Ramirez', 'middle_name_pool': 'Mohamed Abdelkader Mohamed', 'ssid_pool': '0x35d9fd730x6bb3fae6', 'student_id_pool': '630556', 'id': '47885', 'agg_key': {'Polokava-Luna Ramirez'}}])
# ({'Emarosa-Sackmann'}, [{'birth_date_pool': '11/19/1305', 'FIRST_ENTERED_US': '14-JUN-06 12.00.00.000000000 AM', 'first_name_pool': 'Emarosa', 'gender_pool': 'm', 'last_name_pool': 'Sackmann', 'middle_name_pool': 'Bannon', 'ssid_pool': '0x1103cbc60x2207978c', 'student_id_pool': '686797', 'id': '36876', 'agg_key': {'Emarosa-Sackmann'}}])
# ({'Iree-Darby'}, [{'birth_date_pool': '10/18/1594', 'FIRST_ENTERED_US': '27-JUL-09 12.00.00.000000000 AM', 'first_name_pool': 'Iree', 'gender_pool': 'f', 'last_name_pool': 'Darby', 'middle_name_pool': 'Naomi Grace', 'ssid_pool': '0x21b01dc80x43603b90', 'student_id_pool': '279911', 'id': '50028', 'agg_key': {'Iree-Darby'}}])
# ({'Idalie-Cortes Espinoza'}, [{'birth_date_pool': '2/8/2655', 'FIRST_ENTERED_US': '08-OCT-07 12.00.00.000000000 AM', 'first_name_pool': 'Idalie', 'gender_pool': 'f', 'last_name_pool': 'Cortes Espinoza', 'middle_name_pool': 'Everett', 'ssid_pool': '0xadf59d60x15beb3ac', 'student_id_pool': '887760763', 'id': '91694', 'agg_key': {'Idalie-Cortes Espinoza'}}])
# ({'Crissa-Samaniego'}, [{'birth_date_pool': '10/2/2112', 'FIRST_ENTERED_US': '10-JUL-98 12.00.00.000000000 AM', 'first_name_pool': 'Crissa', 'gender_pool': 'n', 'last_name_pool': 'Samaniego', 'middle_name_pool': 'Borisovna', 'ssid_pool': '0x18b1a6470x31634c8e', 'student_id_pool': '987839', 'id': '83427', 'agg_key': {'Crissa-Samaniego'}}])
# ({'Theya-Legarda Garcia'}, [{'birth_date_pool': '9/22/2316', 'FIRST_ENTERED_US': '14-MAR-06 12.00.00.000000000 AM', 'first_name_pool': 'Theya', 'gender_pool': 'f', 'last_name_pool': 'Legarda Garcia', 'middle_name_pool': 'Macoi', 'ssid_pool': '0x982ebaf0x1305d75e', 'student_id_pool': '673944714', 'id': '121654', 'agg_key': {'Theya-Legarda Garcia'}}])
# ({'Julizia-Stijleman-Gilmore'}, [{'birth_date_pool': '2/27/2499', 'FIRST_ENTERED_US': '17-AUG-11 12.00.00.000000000 AM', 'first_name_pool': 'Julizia', 'gender_pool': 'm', 'last_name_pool': 'Stijleman-Gilmore', 'middle_name_pool': 'Mang', 'ssid_pool': '0x1952fba80x32a5f750', 'student_id_pool': '821373', 'id': '120821', 'agg_key': {'Julizia-Stijleman-Gilmore'}}])
# ({'JessLynn-Rember'}, [{'birth_date_pool': '3/2/2143', 'FIRST_ENTERED_US': '11-AUG-15 12.00.00.000000000 AM', 'first_name_pool': 'JessLynn', 'gender_pool': 'n', 'last_name_pool': 'Rember', 'middle_name_pool': 'Zacharias', 'ssid_pool': '0x37284b3e0x6e50967c', 'student_id_pool': '833477', 'id': '21910', 'agg_key': {'JessLynn-Rember'}}])
# ({'Edison-Beltran Castillo'}, [{'birth_date_pool': '6/13/2838', 'FIRST_ENTERED_US': '27-NOV-06 12.00.00.000000000 AM', 'first_name_pool': 'Edison', 'gender_pool': 'f', 'last_name_pool': 'Beltran Castillo', 'middle_name_pool': 'Jermaine', 'ssid_pool': '0x24291d590x48523ab2', 'student_id_pool': '626715', 'id': '123885', 'agg_key': {'Edison-Beltran Castillo'}}])
# ({'Tyrnan-Erichsen'}, [{'birth_date_pool': '2/23/2847', 'FIRST_ENTERED_US': '13-OCT-08 12.00.00.000000000 AM', 'first_name_pool': 'Tyrnan', 'gender_pool': 'n', 'last_name_pool': 'Erichsen', 'middle_name_pool': 'Hawk Barrett', 'ssid_pool': '0x1c52adf90x38a55bf2', 'student_id_pool': '503991', 'id': '10533', 'agg_key': {'Tyrnan-Erichsen'}}])
# ({'Annjeleeah-De Jesus Rojas'}, [{'birth_date_pool': '4/22/2999', 'FIRST_ENTERED_US': '29-JAN-07 12.00.00.000000000 AM', 'first_name_pool': 'Annjeleeah', 'gender_pool': 'n', 'last_name_pool': 'De Jesus Rojas', 'middle_name_pool': 'Steven Cal', 'ssid_pool': '0x2fa4f16d0x5f49e2da', 'student_id_pool': '558035', 'id': '66417', 'agg_key': {'Annjeleeah-De Jesus Rojas'}}])
# ({'Cecelia-Yoder'}, [{'birth_date_pool': '4/24/1698', 'FIRST_ENTERED_US': '05-MAR-02 12.00.00.000000000 AM', 'first_name_pool': 'Cecelia', 'gender_pool': 'n', 'last_name_pool': 'Yoder', 'middle_name_pool': 'Brandon Lew', 'ssid_pool': '0x17ed9b840x2fdb3708', 'student_id_pool': '870155996', 'id': '14598', 'agg_key': {'Cecelia-Yoder'}}])
# ({'Tainley-Seumanu'}, [{'birth_date_pool': '10/14/2116', 'FIRST_ENTERED_US': '09-SEP-98 12.00.00.000000000 AM', 'first_name_pool': 'Tainley', 'gender_pool': 'n', 'last_name_pool': 'Seumanu', 'middle_name_pool': 'Garfield', 'ssid_pool': '0x266af2900x4cd5e520', 'student_id_pool': '952508', 'id': '7325', 'agg_key': {'Tainley-Seumanu'}}])
# ({'Cardai-Gomez Martinez'}, [{'birth_date_pool': '1/20/2264', 'FIRST_ENTERED_US': '05-SEP-00 12.00.00.000000000 AM', 'first_name_pool': 'Cardai', 'gender_pool': 'f', 'last_name_pool': 'Gomez Martinez', 'middle_name_pool': 'Aidukaitis', 'ssid_pool': '0x15bc5c7e0x2b78b8fc', 'student_id_pool': '288551', 'id': '30532', 'agg_key': {'Cardai-Gomez Martinez'}}])
# ({'ShayLynn-Zazueta Rios'}, [{'birth_date_pool': '5/22/1975', 'FIRST_ENTERED_US': '24-SEP-01 12.00.00.000000000 AM', 'first_name_pool': 'ShayLynn', 'gender_pool': 'f', 'last_name_pool': 'Zazueta Rios', 'middle_name_pool': 'Carson Jack', 'ssid_pool': '0x184f21c10x309e4382', 'student_id_pool': '571060', 'id': '13147', 'agg_key': {'ShayLynn-Zazueta Rios'}}])
# ({"E'zra-Mahnken"}, [{'birth_date_pool': '11/19/2418', 'FIRST_ENTERED_US': '30-OCT-01 12.00.00.000000000 AM', 'first_name_pool': "E'zra", 'gender_pool': 'n', 'last_name_pool': 'Mahnken', 'middle_name_pool': 'JaNan', 'ssid_pool': '0x25dd2d0b0x4bba5a16', 'student_id_pool': '736860', 'id': '127305', 'agg_key': {"E'zra-Mahnken"}}])
# ({'Ishanvi-Myles-Gresham'}, [{'birth_date_pool': '1/15/2565', 'FIRST_ENTERED_US': '28-FEB-01 12.00.00.000000000 AM', 'first_name_pool': 'Ishanvi', 'gender_pool': 'f', 'last_name_pool': 'Myles-Gresham', 'middle_name_pool': 'Annalyn', 'ssid_pool': '0xdc6f1420x1b8de284', 'student_id_pool': '939791', 'id': '51171', 'agg_key': {'Ishanvi-Myles-Gresham'}}])
# ({'Emersen-Canenguez'}, [{'birth_date_pool': '4/17/1317', 'FIRST_ENTERED_US': '02-AUG-06 12.00.00.000000000 AM', 'first_name_pool': 'Emersen', 'gender_pool': 'm', 'last_name_pool': 'Canenguez', 'middle_name_pool': 'Kahuilaokalani', 'ssid_pool': '0x276a17100x4ed42e20', 'student_id_pool': '845821', 'id': '14640', 'agg_key': {'Emersen-Canenguez'}}])
# ({'Huckleberry-Emmanuel'}, [{'birth_date_pool': '2/21/2332', 'FIRST_ENTERED_US': '04-SEP-11 12.00.00.000000000 AM', 'first_name_pool': 'Huckleberry', 'gender_pool': 'm', 'last_name_pool': 'Emmanuel', 'middle_name_pool': "Kenneth Tuisamoa Sa'Anapu", 'ssid_pool': '0x1cdd7a870x39baf50e', 'student_id_pool': '543230297', 'id': '47077', 'agg_key': {'Huckleberry-Emmanuel'}}])
# ({'Kamara-Holtz'}, [{'birth_date_pool': '2/24/1257', 'FIRST_ENTERED_US': '22-AUG-15 12.00.00.000000000 AM', 'first_name_pool': 'Kamara', 'gender_pool': 'm', 'last_name_pool': 'Holtz', 'middle_name_pool': 'Kyra', 'ssid_pool': '0x10931d3c0x21263a78', 'student_id_pool': '665231', 'id': '55426', 'agg_key': {'Kamara-Holtz'}}])
# ({'Tiberius-Bruerton'}, [{'birth_date_pool': '2/3/1274', 'FIRST_ENTERED_US': '05-AUG-02 12.00.00.000000000 AM', 'first_name_pool': 'Tiberius', 'gender_pool': 'f', 'last_name_pool': 'Bruerton', 'middle_name_pool': 'Josiah Aumua', 'ssid_pool': '0x159f459e0x2b3e8b3c', 'student_id_pool': '835384', 'id': '123720', 'agg_key': {'Tiberius-Bruerton'}}])
# ({'Kaushiki-De Santiago Albino'}, [{'birth_date_pool': '8/17/1901', 'FIRST_ENTERED_US': '04-JUL-98 12.00.00.000000000 AM', 'first_name_pool': 'Kaushiki', 'gender_pool': 'n', 'last_name_pool': 'De Santiago Albino', 'middle_name_pool': 'Venicio', 'ssid_pool': '0x3a94e54a0x7529ca94', 'student_id_pool': '997886', 'id': '15047', 'agg_key': {'Kaushiki-De Santiago Albino'}}])
# ({'Zakai-Osorio'}, [{'birth_date_pool': '10/2/1822', 'FIRST_ENTERED_US': '01-JAN-98 12.00.00.000000000 AM', 'first_name_pool': 'Zakai', 'gender_pool': 'n', 'last_name_pool': 'Osorio', 'middle_name_pool': 'Atlas', 'ssid_pool': '0x261bcf1b0x4c379e36', 'student_id_pool': '326424', 'id': '32182', 'agg_key': {'Zakai-Osorio'}}])
# ({'MaCord-Edmunds'}, [{'birth_date_pool': '8/9/1671', 'FIRST_ENTERED_US': '05-AUG-14 12.00.00.000000000 AM', 'first_name_pool': 'MaCord', 'gender_pool': 'm', 'last_name_pool': 'Edmunds', 'middle_name_pool': 'Lowry', 'ssid_pool': '0x2f4568740x5e8ad0e8', 'student_id_pool': '237011', 'id': '86516', 'agg_key': {'MaCord-Edmunds'}}])
# ({'Oudom-Siegel'}, [{'birth_date_pool': '6/16/1414', 'FIRST_ENTERED_US': '01-SEP-00 12.00.00.000000000 AM', 'first_name_pool': 'Oudom', 'gender_pool': 'n', 'last_name_pool': 'Siegel', 'middle_name_pool': 'Lamon', 'ssid_pool': '0x2207637c0x440ec6f8', 'student_id_pool': '348803', 'id': '13434', 'agg_key': {'Oudom-Siegel'}}])
# ({'Delila-Gardiner'}, [{'birth_date_pool': '1/15/2144', 'FIRST_ENTERED_US': '01-APR-06 12.00.00.000000000 AM', 'first_name_pool': 'Delila', 'gender_pool': 'm', 'last_name_pool': 'Gardiner', 'middle_name_pool': 'Viswa', 'ssid_pool': '0x2bccb4ae0x5799695c', 'student_id_pool': '394290', 'id': '56615', 'agg_key': {'Delila-Gardiner'}}])
# ({'Logynn-Mendoza Castro'}, [{'birth_date_pool': '8/2/2547', 'FIRST_ENTERED_US': '13-JUL-04 12.00.00.000000000 AM', 'first_name_pool': 'Logynn', 'gender_pool': 'f', 'last_name_pool': 'Mendoza Castro', 'middle_name_pool': 'Kazuhiro Siaosi', 'ssid_pool': '0x9aa0f8b0x13541f16', 'student_id_pool': '475105', 'id': '136363', 'agg_key': {'Logynn-Mendoza Castro'}}])
# ({'Jacey-Hunziker'}, [{'birth_date_pool': '8/23/2923', 'FIRST_ENTERED_US': '15-SEP-00 12.00.00.000000000 AM', 'first_name_pool': 'Jacey', 'gender_pool': 'n', 'last_name_pool': 'Hunziker', 'middle_name_pool': 'Layoni', 'ssid_pool': '0x1561c3b90x2ac38772', 'student_id_pool': '811182', 'id': '44099', 'agg_key': {'Jacey-Hunziker'}}])
# ({'Sydnee-Yerke'}, [{'birth_date_pool': '4/11/1326', 'FIRST_ENTERED_US': '08-JAN-07 12.00.00.000000000 AM', 'first_name_pool': 'Sydnee', 'gender_pool': 'f', 'last_name_pool': 'Yerke', 'middle_name_pool': 'Rufus', 'ssid_pool': '0x3b529b760x76a536ec', 'student_id_pool': '860552', 'id': '56111', 'agg_key': {'Sydnee-Yerke'}}])
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## Via DataFrames API
# Beam DataFrames offer more table-like behaviors.  Some functionality hasn't been implemented yet (apply won't work)

# %%
# Build the pipeline
with beam.Pipeline() as p:
    # Use the runner to load data and put it into a dataframe (there are pcollection to frame commands as well)
    df = p | read_csv(test_file_path)
    
    aggregated = df[agg_set]\
        .groupby(agg_set)\
        .count()
#         .apply(lambda x: x.index.to_list())
    
    # Output the frame directly (can go to csv or BigQuery)
    aggregated.to_csv(output_file_path)  # Needs more kwargs to be useful, but output is possible already

    # Convert back to PCollection for more stuff if needed - in general, don't do this. Very slow.
#     agg_pc = to_pcollection(aggregated)
